# %%
import sys

sys.path.append("..")

# %% [markdown]
# ### Careful if you are running the code on Mac, the paths change ... they use the " / " differently

# %% [markdown]
# Rotation

# %%
import os
from src import ingest_data
import shutil


BASE_DIR = os.path.abspath("../") 
input_root = os.path.join(BASE_DIR, "data/raw/train")
output_root = os.path.join(BASE_DIR, "data/processed/train_augmented_rotated")


os.makedirs(output_root, exist_ok=True)


for class_name in os.listdir(input_root):

    class_input_folder = os.path.join(input_root, class_name)
    class_output_folder = os.path.join(output_root, class_name)

    if not os.path.isdir(class_input_folder):
        continue

    os.makedirs(class_output_folder, exist_ok=True)

    image_files = sorted(
        [f for f in os.listdir(class_input_folder) if f.lower().endswith(".png")]
    )

    

    for i, img_name in enumerate(image_files):
        

        if i % 1000 == 0 and i != 0 :
            print(f"{i} images processed for class {class_name}")

        input_path = os.path.join(class_input_folder, img_name)
        output_path = os.path.join(class_output_folder, img_name)
        output_path = output_path.replace(".png", "_rotated.png")


        args = [input_path, output_path]

        args.append("--rotate")

        # Copy original file
        output_path = output_path.replace("_rotated.png", ".png")
        shutil.copy2(input_path, output_path)
        # Create augmented version

        ingest_data(standalone_mode=False, args=args)
# Out:
# 1000 images processed for class airplane
# 2000 images processed for class airplane
# 3000 images processed for class airplane
# 4000 images processed for class airplane
# 5000 images processed for class airplane
# 6000 images processed for class airplane
# 7000 images processed for class airplane
# 8000 images processed for class airplane
# 1000 images processed for class automobile
# 2000 images processed for class automobile
# 3000 images processed for class automobile
# 4000 images processed for class automobile
# 5000 images processed for class automobile
# 6000 images processed for class automobile
# 7000 images processed for class automobile
# 8000 images processed for class automobile
# 1000 images processed for class bird
# 2000 images processed for class bird
# 3000 images processed for class bird
# 4000 images processed for class bird
# 5000 images processed for class bird
# 6000 images processed for class bird
# 7000 images processed for class bird
# 8000 images processed for class bird
# 1000 images processed for class cat
# 2000 images processed for class cat
# 3000 images processed for class cat
# 4000 images processed for class cat
# 5000 images processed for class cat
# 6000 images processed for class cat
# 7000 images processed for class cat
# 8000 images processed for class cat
# 1000 images processed for class deer
# 2000 images processed for class deer
# 3000 images processed for class deer
# 4000 images processed for class deer
# 5000 images processed for class deer
# 6000 images processed for class deer
# 7000 images processed for class deer
# 8000 images processed for class deer
# 1000 images processed for class dog
# 2000 images processed for class dog
# 3000 images processed for class dog
# 4000 images processed for class dog
# 5000 images processed for class dog
# 6000 images processed for class dog
# 7000 images processed for class dog
# 8000 images processed for class dog
# 1000 images processed for class frog
# 2000 images processed for class frog
# 3000 images processed for class frog
# 4000 images processed for class frog
# 5000 images processed for class frog
# 6000 images processed for class frog
# 7000 images processed for class frog
# 8000 images processed for class frog
# 1000 images processed for class horse
# 2000 images processed for class horse
# 3000 images processed for class horse
# 4000 images processed for class horse
# 5000 images processed for class horse
# 6000 images processed for class horse
# 7000 images processed for class horse
# 8000 images processed for class horse
# 1000 images processed for class ship
# 2000 images processed for class ship
# 3000 images processed for class ship
# 4000 images processed for class ship
# 5000 images processed for class ship
# 6000 images processed for class ship
# 7000 images processed for class ship
# 8000 images processed for class ship
# 1000 images processed for class truck
# 2000 images processed for class truck
# 3000 images processed for class truck
# 4000 images processed for class truck
# 5000 images processed for class truck
# 6000 images processed for class truck
# 7000 images processed for class truck
# 8000 images processed for class truck

# %% [markdown]
# Brightness and contrast

# %%
import os
from src import ingest_data
import shutil

BASE_DIR = os.path.abspath("../")
input_root = os.path.join(BASE_DIR, "data/processed/train_augmented_rotated")
output_root = os.path.join(BASE_DIR, "data/processed/train_augmented_rotated_brightness_contrast")
os.makedirs(output_root, exist_ok=True)

for class_name in os.listdir(input_root):
    class_input_folder = os.path.join(input_root, class_name)
    class_output_folder = os.path.join(output_root, class_name)
    
    if not os.path.isdir(class_input_folder):
        continue
        
    os.makedirs(class_output_folder, exist_ok=True)
    
    image_files = sorted(
        [f for f in os.listdir(class_input_folder) if f.lower().endswith(".png")]
    )
    
    l = 0
    for i, img_name in enumerate(image_files):
        l += 1
            
        if i % 1000 == 0 and i != 0:
            print(f"{i} images processed for class {class_name}")
            
        input_path = os.path.join(class_input_folder, img_name)
        
        # Copy original file
        orig_output_path = os.path.join(class_output_folder, img_name)
        shutil.copy2(input_path, orig_output_path)
        
        # Create augmented version
        aug_output_path = os.path.join(class_output_folder, img_name.replace(".png", "_brightness_contrast.png"))
        
        args = [input_path, aug_output_path, "--brightness", "--contrast"]
        ingest_data(standalone_mode=False, args=args)
# Out:
# 1000 images processed for class airplane
# 2000 images processed for class airplane
# 3000 images processed for class airplane
# 4000 images processed for class airplane
# 5000 images processed for class airplane
# 6000 images processed for class airplane
# 7000 images processed for class airplane
# 8000 images processed for class airplane
# 9000 images processed for class airplane
# 10000 images processed for class airplane
# 11000 images processed for class airplane
# 12000 images processed for class airplane
# 13000 images processed for class airplane
# 14000 images processed for class airplane
# 15000 images processed for class airplane
# 16000 images processed for class airplane
# 17000 images processed for class airplane
# 1000 images processed for class automobile
# 2000 images processed for class automobile
# 3000 images processed for class automobile
# 4000 images processed for class automobile
# 5000 images processed for class automobile
# 6000 images processed for class automobile
# 7000 images processed for class automobile
# 8000 images processed for class automobile
# 9000 images processed for class automobile
# 10000 images processed for class automobile
# 11000 images processed for class automobile
# 12000 images processed for class automobile
# 13000 images processed for class automobile
# 14000 images processed for class automobile
# 15000 images processed for class automobile
# 16000 images processed for class automobile
# 17000 images processed for class automobile
# 1000 images processed for class bird
# 2000 images processed for class bird
# 3000 images processed for class bird
# 4000 images processed for class bird
# 5000 images processed for class bird
# 6000 images processed for class bird
# 7000 images processed for class bird
# 8000 images processed for class bird
# 9000 images processed for class bird
# 10000 images processed for class bird
# 11000 images processed for class bird
# 12000 images processed for class bird
# 13000 images processed for class bird
# 14000 images processed for class bird
# 15000 images processed for class bird
# 16000 images processed for class bird
# 17000 images processed for class bird
# 1000 images processed for class cat
# 2000 images processed for class cat
# 3000 images processed for class cat
# 4000 images processed for class cat
# 5000 images processed for class cat
# 6000 images processed for class cat
# 7000 images processed for class cat
# 8000 images processed for class cat
# 9000 images processed for class cat
# 10000 images processed for class cat
# 11000 images processed for class cat
# 12000 images processed for class cat
# 13000 images processed for class cat
# 14000 images processed for class cat
# 15000 images processed for class cat
# 16000 images processed for class cat
# 17000 images processed for class cat
# 1000 images processed for class deer
# 2000 images processed for class deer
# 3000 images processed for class deer
# 4000 images processed for class deer
# 5000 images processed for class deer
# 6000 images processed for class deer
# 7000 images processed for class deer
# 8000 images processed for class deer
# 9000 images processed for class deer
# 10000 images processed for class deer
# 11000 images processed for class deer
# 12000 images processed for class deer
# 13000 images processed for class deer
# 14000 images processed for class deer
# 15000 images processed for class deer
# 16000 images processed for class deer
# 17000 images processed for class deer
# 1000 images processed for class dog
# 2000 images processed for class dog
# 3000 images processed for class dog
# 4000 images processed for class dog
# 5000 images processed for class dog
# 6000 images processed for class dog
# 7000 images processed for class dog
# 8000 images processed for class dog
# 9000 images processed for class dog
# 10000 images processed for class dog
# 11000 images processed for class dog
# 12000 images processed for class dog
# 13000 images processed for class dog
# 14000 images processed for class dog
# 15000 images processed for class dog
# 16000 images processed for class dog
# 17000 images processed for class dog
# 1000 images processed for class frog
# 2000 images processed for class frog
# 3000 images processed for class frog
# 4000 images processed for class frog
# 5000 images processed for class frog
# 6000 images processed for class frog
# 7000 images processed for class frog
# 8000 images processed for class frog
# 9000 images processed for class frog
# 10000 images processed for class frog
# 11000 images processed for class frog
# 12000 images processed for class frog
# 13000 images processed for class frog
# 14000 images processed for class frog
# 15000 images processed for class frog
# 16000 images processed for class frog
# 17000 images processed for class frog
# 1000 images processed for class horse
# 2000 images processed for class horse
# 3000 images processed for class horse
# 4000 images processed for class horse
# 5000 images processed for class horse
# 6000 images processed for class horse
# 7000 images processed for class horse
# 8000 images processed for class horse
# 9000 images processed for class horse
# 10000 images processed for class horse
# 11000 images processed for class horse
# 12000 images processed for class horse
# 13000 images processed for class horse
# 14000 images processed for class horse
# 15000 images processed for class horse
# 16000 images processed for class horse
# 17000 images processed for class horse
# 1000 images processed for class ship
# 2000 images processed for class ship
# 3000 images processed for class ship
# 4000 images processed for class ship
# 5000 images processed for class ship
# 6000 images processed for class ship
# 7000 images processed for class ship
# 8000 images processed for class ship
# 9000 images processed for class ship
# 10000 images processed for class ship
# 11000 images processed for class ship
# 12000 images processed for class ship
# 13000 images processed for class ship
# 14000 images processed for class ship
# 15000 images processed for class ship
# 16000 images processed for class ship
# 17000 images processed for class ship
# 1000 images processed for class truck
# 2000 images processed for class truck
# 3000 images processed for class truck
# 4000 images processed for class truck
# 5000 images processed for class truck
# 6000 images processed for class truck
# 7000 images processed for class truck
# 8000 images processed for class truck
# 9000 images processed for class truck
# 10000 images processed for class truck
# 11000 images processed for class truck
# 12000 images processed for class truck
# 13000 images processed for class truck
# 14000 images processed for class truck
# 15000 images processed for class truck
# 16000 images processed for class truck
# 17000 images processed for class truck

# %% [markdown]
# FLip the images

# %%
import os
from src import ingest_data
import shutil

BASE_DIR = os.path.abspath("../")
input_root = os.path.join(BASE_DIR, "data/raw/train")
output_root = os.path.join(BASE_DIR, "data/processed/train_augmented_flipped")
os.makedirs(output_root, exist_ok=True)

for class_name in os.listdir(input_root):
    class_input_folder = os.path.join(input_root, class_name)
    class_output_folder = os.path.join(output_root, class_name)
    
    if not os.path.isdir(class_input_folder):
        continue
        
    os.makedirs(class_output_folder, exist_ok=True)
    
    image_files = sorted(
        [f for f in os.listdir(class_input_folder) if f.lower().endswith(".png")]
    )
    
    l = 0
    for i, img_name in enumerate(image_files):
        l += 1
        if l > 8:
            break
            
        if i % 1000 == 0 and i != 0:
            print(f"{i} images processed for class {class_name}")
            
        input_path = os.path.join(class_input_folder, img_name)
        
        # Copy original file
        orig_output_path = os.path.join(class_output_folder, img_name)
        shutil.copy2(input_path, orig_output_path)
        
        # Create augmented version with flip
        flipped_output_path = os.path.join(class_output_folder, img_name.replace(".png", "_flipped.png"))
        
        args = [input_path, flipped_output_path, "--flip"]
        ingest_data(standalone_mode=False, args=args)
# Out:
# ---------------------------------------------------------------------------
# BadOptionUsage                            Traceback (most recent call last)
# Cell In[4], line 53
#      50 shutil.copy2(input_path, output_path)
#      51 # Create augmented version
# ---> 53 ingest_data(standalone_mode=False, args=args)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\click\core.py:1157, in BaseCommand.__call__(self, *args, **kwargs)
#    1155 def __call__(self, *args: t.Any, **kwargs: t.Any) -> t.Any:
#    1156     """Alias for :meth:`main`."""
# -> 1157     return self.main(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\click\core.py:1077, in BaseCommand.main(self, args, prog_name, complete_var, standalone_mode, windows_expand_args, **extra)
#    1075 try:
#    1076     try:
# -> 1077         with self.make_context(prog_name, args, **extra) as ctx:
#    1078             rv = self.invoke(ctx)
#    1079             if not standalone_mode:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\click\core.py:943, in BaseCommand.make_context(self, info_name, args, parent, **extra)
#     938 ctx = self.context_class(
#     939     self, info_name=info_name, parent=parent, **extra  # type: ignore
#     940 )
#     942 with ctx.scope(cleanup=False):
# --> 943     self.parse_args(ctx, args)
#     944 return ctx
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\click\core.py:1405, in Command.parse_args(self, ctx, args)
#    1402     ctx.exit()
#    1404 parser = self.make_parser(ctx)
# -> 1405 opts, args, param_order = parser.parse_args(args=args)
#    1407 for param in iter_params_for_processing(param_order, self.get_params(ctx)):
#    1408     value, args = param.handle_parse_result(ctx, opts, args)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\click\parser.py:337, in OptionParser.parse_args(self, args)
#     335 state = ParsingState(args)
#     336 try:
# --> 337     self._process_args_for_options(state)
#     338     self._process_args_for_args(state)
#     339 except UsageError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\click\parser.py:364, in OptionParser._process_args_for_options(self, state)
#     362     return
#     363 elif arg[:1] in self._opt_prefixes and arglen > 1:
# --> 364     self._process_opts(arg, state)
#     365 elif self.allow_interspersed_args:
#     366     state.largs.append(arg)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\click\parser.py:514, in OptionParser._process_opts(self, arg, state)
#     510 # At this point we will match the (assumed) long option through
#     511 # the long option matching code.  Note that this allows options
#     512 # like "-foo" to be matched as long options.
#     513 try:
# --> 514     self._match_long_opt(norm_long_opt, explicit_value, state)
#     515 except NoSuchOption:
#     516     # At this point the long option matching failed, and we need
#     517     # to try with short options.  However there is a special rule
#    (...)
#     520     # short option code and will instead raise the no option
#     521     # error.
#     522     if arg[:2] not in self._opt_prefixes:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\click\parser.py:409, in OptionParser._match_long_opt(self, opt, explicit_value, state)
#     406     if explicit_value is not None:
#     407         state.rargs.insert(0, explicit_value)
# --> 409     value = self._get_value_from_state(opt, option, state)
#     411 elif explicit_value is not None:
#     412     raise BadOptionUsage(
#     413         opt, _("Option {name!r} does not take a value.").format(name=opt)
#     414     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\click\parser.py:471, in OptionParser._get_value_from_state(self, option_name, option, state)
#     469         value = _flag_needs_value
#     470     else:
# --> 471         raise BadOptionUsage(
#     472             option_name,
#     473             ngettext(
#     474                 "Option {name!r} requires an argument.",
#     475                 "Option {name!r} requires {nargs} arguments.",
#     476                 nargs,
#     477             ).format(name=option_name, nargs=nargs),
#     478         )
#     479 elif nargs == 1:
#     480     next_rarg = state.rargs[0]
#
# BadOptionUsage: Option '--flip' requires an argument.
